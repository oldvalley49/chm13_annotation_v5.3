# %%
import pandas as pd
import gffpandas.gffpandas as gffpd
import os
os.chdir("/home/tfuruta1/CHM13_changes")

# %%
# load JHU annotation

JHU = gffpd.read_gff3("../MANE_CHM13/data/chm13v2.0_RefSeq_Liftoff_v5.2.gff3")
JHU_df = JHU.attributes_to_columns()

# %%
# load changes
add = pd.read_csv("changes/1_synonyms_add.csv", index_col = 0)
remove = pd.read_csv("changes/1_synonyms_remove.csv", index_col = 0)

# %%
# example - remove

gene = remove.iloc[0, :]
match = JHU_df[
    (JHU_df.type == 'gene')
    & (JHU_df.gene == gene.gene)
    & (JHU_df.seq_id == gene.chromosome)
    & (JHU_df.start == gene.start)
    & (JHU_df.end == gene.end)
    & (JHU_df.strand == gene.strand)
].iloc[0]

# raise warning if multiple entries
match
# Out:
# seq_id                     chr1
# source                  Liftoff
# type                       gene
# start                  32601643
# end                    32634754
#                          ...
# unfiltered_paralogy        None
# valid_ORF                  None
# valid_ORFs                    4
# valid_start                None
# valid_stop                 None
# Name: 98830, Length: 69, dtype: object

# %%
match.name
# Out:
# np.int64(98830)

# %%
next = JHU_df[match.name + 1:]
next_gene = next[next['type'] == 'gene']
next_gene.iloc[0].name
# Out:
# np.int64(98887)

# %%
drop_idx = JHU_df[match.name: next_gene.iloc[0].name].index

# %%
test = JHU_df.drop(drop_idx)

# %%
JHU_df.iloc[98880:98890]
# Out:
#       seq_id   source        type     start       end score strand phase  \
# 98880   chr1  Liftoff        exon  32628435  32628558     .      +     .
# 98881   chr1  Liftoff        exon  32632649  32634754     .      +     .
# 98882   chr1  Liftoff         CDS  32625553  32625610     .      +     0
# 98883   chr1  Liftoff         CDS  32627570  32627740     .      +     2
# 98884   chr1  Liftoff         CDS  32627845  32627900     .      +     2
# 98885   chr1  Liftoff         CDS  32628435  32628558     .      +     0
# 98886   chr1  Liftoff         CDS  32632649  32632671     .      +     2
# 98887   chr1  Liftoff        gene  32635023  32677140     .      -     .
# 98888   chr1  Liftoff  transcript  32635023  32677140     .      -     .
# 98889   chr1  Liftoff        exon  32635023  32635875     .      -     .
#
#                                               attributes Dbxref  ...  \
# 98880  Parent=NM_001198973.2;db_xref=GeneID:57648;gen...   None  ...
# 98881  Parent=NM_001198973.2;db_xref=GeneID:57648;gen...   None  ...
# 98882  Parent=NM_001198973.2;db_xref=GeneID:57648;gbk...   None  ...
# 98883  Parent=NM_001198973.2;db_xref=GeneID:57648;gbk...   None  ...
# 98884  Parent=NM_001198973.2;db_xref=GeneID:57648;gbk...   None  ...
# 98885  Parent=NM_001198973.2;db_xref=GeneID:57648;gbk...   None  ...
# 98886  Parent=NM_001198973.2;db_xref=GeneID:57648;gbk...   None  ...
# 98887  ID=YARS1;gene_name=YARS1;db_xref=MIM:603623;de...   None  ...
# 98888  ID=NM_003680.4;Parent=YARS1;db_xref=GeneID:856...   None  ...
# 98889  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
#
#       transcript_id transcript_modes transcript_name transferase  \
# 98880          None             None            None        None
# 98881          None             None            None        None
# 98882          None             None            None        None
# 98883          None             None            None        None
# 98884          None             None            None        None
# 98885          None             None            None        None
# 98886          None             None            None        None
# 98887          None             None            None        None
# 98888          None             None            None        None
# 98889          None             None            None        None
#
#       transl_except unfiltered_paralogy valid_ORF valid_ORFs valid_start  \
# 98880          None                None      None       None        None
# 98881          None                None      None       None        None
# 98882          None                None      None       None        None
# 98883          None                None      None       None        None
# 98884          None                None      None       None        None
# 98885          None                None      None       None        None
# 98886          None                None      None       None        None
# 98887          None                None      None          2        None
# 98888          None                None      True       None        None
# 98889          None                None      None       None        None
#
#       valid_stop
# 98880       None
# 98881       None
# 98882       None
# 98883       None
# 98884       None
# 98885       None
# 98886       None
# 98887       None
# 98888       None
# 98889       None
#
# [10 rows x 69 columns]

# %%
test.iloc[98820:98835]
# Out:
#       seq_id   source        type     start       end score strand phase  \
# 98820   chr1  Liftoff         CDS  32554689  32555868     .      -     1
# 98821   chr1  Liftoff         CDS  32562428  32562480     .      -     0
# 98822   chr1  Liftoff  transcript  32539874  32563413     .      -     .
# 98823   chr1  Liftoff        exon  32539874  32543881     .      -     .
# 98824   chr1  Liftoff        exon  32544050  32544174     .      -     .
# 98825   chr1  Liftoff        exon  32554689  32555868     .      -     .
# 98826   chr1  Liftoff        exon  32563371  32563413     .      -     .
# 98827   chr1  Liftoff         CDS  32543578  32543881     .      -     1
# 98828   chr1  Liftoff         CDS  32544050  32544174     .      -     0
# 98829   chr1  Liftoff         CDS  32554689  32555657     .      -     0
# 98887   chr1  Liftoff        gene  32635023  32677140     .      -     .
# 98888   chr1  Liftoff  transcript  32635023  32677140     .      -     .
# 98889   chr1  Liftoff        exon  32635023  32635875     .      -     .
# 98890   chr1  Liftoff        exon  32639166  32639307     .      -     .
# 98891   chr1  Liftoff        exon  32639869  32640062     .      -     .
#
#                                               attributes Dbxref  ...  \
# 98820  Parent=XM_024450010.2;db_xref=GeneID:81493;gbk...   None  ...
# 98821  Parent=XM_024450010.2;db_xref=GeneID:81493;gbk...   None  ...
# 98822  ID=XM_024450013.2;Parent=SYNC;db_xref=GeneID:8...   None  ...
# 98823  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98824  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98825  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98826  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98827  Parent=XM_024450013.2;db_xref=GeneID:81493;gbk...   None  ...
# 98828  Parent=XM_024450013.2;db_xref=GeneID:81493;gbk...   None  ...
# 98829  Parent=XM_024450013.2;db_xref=GeneID:81493;gbk...   None  ...
# 98887  ID=YARS1;gene_name=YARS1;db_xref=MIM:603623;de...   None  ...
# 98888  ID=NM_003680.4;Parent=YARS1;db_xref=GeneID:856...   None  ...
# 98889  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
# 98890  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
# 98891  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
#
#       transcript_id transcript_modes transcript_name transferase  \
# 98820          None             None            None        None
# 98821          None             None            None        None
# 98822          None             None            None        None
# 98823          None             None            None        None
# 98824          None             None            None        None
# 98825          None             None            None        None
# 98826          None             None            None        None
# 98827          None             None            None        None
# 98828          None             None            None        None
# 98829          None             None            None        None
# 98887          None             None            None        None
# 98888          None             None            None        None
# 98889          None             None            None        None
# 98890          None             None            None        None
# 98891          None             None            None        None
#
#       transl_except unfiltered_paralogy valid_ORF valid_ORFs valid_start  \
# 98820          None                None      None       None        None
# 98821          None                None      None       None        None
# 98822          None                None      True       None        None
# 98823          None                None      None       None        None
# 98824          None                None      None       None        None
# 98825          None                None      None       None        None
# 98826          None                None      None       None        None
# 98827          None                None      None       None        None
# 98828          None                None      None       None        None
# 98829          None                None      None       None        None
# 98887          None                None      None          2        None
# 98888          None                None      True       None        None
# 98889          None                None      None       None        None
# 98890          None                None      None       None        None
# 98891          None                None      None       None        None
#
#       valid_stop
# 98820       None
# 98821       None
# 98822       None
# 98823       None
# 98824       None
# 98825       None
# 98826       None
# 98827       None
# 98828       None
# 98829       None
# 98887       None
# 98888       None
# 98889       None
# 98890       None
# 98891       None
#
# [15 rows x 69 columns]

# %%
def remove_feature(df, row):
    next_df = df[row.name + 1:]
    next_gene = next_df[next_df['type'] == 'gene']
    if next_gene.empty:
        drop_idx = df.loc[row.name : ].index
    else:
        drop_idx = df[row.name:next_gene.iloc[0].name].index
    return df.drop(drop_idx)

# %%
test = remove_feature(JHU_df, match)

# %%
def remove_genes(df, remove_df):
    for _, gene in remove_df.iterrows():
        match = df[
            (df.type == 'gene')
            & (df.gene == gene.gene)
            & (df.seq_id == gene.chromosome)
            & (df.start == gene.start)
            & (df.end == gene.end)
            & (df.strand == gene.strand)
        ]
        if matches.empty:
            continue
        else:
            match = matches.iloc[0]
            df = remove_feature(df, gene)

# %%
test = remove_genes(JHU_df, remove)

# %%
test.iloc[98820:98835]
# Out:
#       seq_id   source        type     start       end score strand phase  \
# 98820   chr1  Liftoff         CDS  32554689  32555868     .      -     1
# 98821   chr1  Liftoff         CDS  32562428  32562480     .      -     0
# 98822   chr1  Liftoff  transcript  32539874  32563413     .      -     .
# 98823   chr1  Liftoff        exon  32539874  32543881     .      -     .
# 98824   chr1  Liftoff        exon  32544050  32544174     .      -     .
# 98825   chr1  Liftoff        exon  32554689  32555868     .      -     .
# 98826   chr1  Liftoff        exon  32563371  32563413     .      -     .
# 98827   chr1  Liftoff         CDS  32543578  32543881     .      -     1
# 98828   chr1  Liftoff         CDS  32544050  32544174     .      -     0
# 98829   chr1  Liftoff         CDS  32554689  32555657     .      -     0
# 98887   chr1  Liftoff        gene  32635023  32677140     .      -     .
# 98888   chr1  Liftoff  transcript  32635023  32677140     .      -     .
# 98889   chr1  Liftoff        exon  32635023  32635875     .      -     .
# 98890   chr1  Liftoff        exon  32639166  32639307     .      -     .
# 98891   chr1  Liftoff        exon  32639869  32640062     .      -     .
#
#                                               attributes Dbxref  ...  \
# 98820  Parent=XM_024450010.2;db_xref=GeneID:81493;gbk...   None  ...
# 98821  Parent=XM_024450010.2;db_xref=GeneID:81493;gbk...   None  ...
# 98822  ID=XM_024450013.2;Parent=SYNC;db_xref=GeneID:8...   None  ...
# 98823  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98824  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98825  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98826  Parent=XM_024450013.2;db_xref=GeneID:81493;exp...   None  ...
# 98827  Parent=XM_024450013.2;db_xref=GeneID:81493;gbk...   None  ...
# 98828  Parent=XM_024450013.2;db_xref=GeneID:81493;gbk...   None  ...
# 98829  Parent=XM_024450013.2;db_xref=GeneID:81493;gbk...   None  ...
# 98887  ID=YARS1;gene_name=YARS1;db_xref=MIM:603623;de...   None  ...
# 98888  ID=NM_003680.4;Parent=YARS1;db_xref=GeneID:856...   None  ...
# 98889  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
# 98890  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
# 98891  Parent=NM_003680.4;db_xref=GeneID:8565;gene=YA...   None  ...
#
#       transcript_id transcript_modes transcript_name transferase  \
# 98820          None             None            None        None
# 98821          None             None            None        None
# 98822          None             None            None        None
# 98823          None             None            None        None
# 98824          None             None            None        None
# 98825          None             None            None        None
# 98826          None             None            None        None
# 98827          None             None            None        None
# 98828          None             None            None        None
# 98829          None             None            None        None
# 98887          None             None            None        None
# 98888          None             None            None        None
# 98889          None             None            None        None
# 98890          None             None            None        None
# 98891          None             None            None        None
#
#       transl_except unfiltered_paralogy valid_ORF valid_ORFs valid_start  \
# 98820          None                None      None       None        None
# 98821          None                None      None       None        None
# 98822          None                None      True       None        None
# 98823          None                None      None       None        None
# 98824          None                None      None       None        None
# 98825          None                None      None       None        None
# 98826          None                None      None       None        None
# 98827          None                None      None       None        None
# 98828          None                None      None       None        None
# 98829          None                None      None       None        None
# 98887          None                None      None          2        None
# 98888          None                None      True       None        None
# 98889          None                None      None       None        None
# 98890          None                None      None       None        None
# 98891          None                None      None       None        None
#
#       valid_stop
# 98820       None
# 98821       None
# 98822       None
# 98823       None
# 98824       None
# 98825       None
# 98826       None
# 98827       None
# 98828       None
# 98829       None
# 98887       None
# 98888       None
# 98889       None
# 98890       None
# 98891       None
#
# [15 rows x 69 columns]
